# %%
# Library imports
import cadquery as cq

# %%
lower_base=cq.Workplane().rect(100, 50).extrude(20)
inner_lower_base=cq.Workplane().rect(95, 45).extrude(15)
lower_base.cut(inner_lower_base).fillet(1)
