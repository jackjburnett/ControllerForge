# %%
# Library imports
import cadquery as cq

# %%
# Set variables
base_height=50
base_width= 300
base_length= 100
wall_thickness = 5
rounded_edges= False
screws = False
corner_radius=5

# %%
# Generate bottom of base
bottom_base=cq.Workplane().rect(base_width, base_length).extrude(base_height)
inner_base=cq.Workplane().rect(base_width-(wall_thickness*2), base_length-(wall_thickness*2)).extrude(base_height-(wall_thickness))
bottom_base=bottom_base.cut(inner_base)
bottom_base

# %%
# Add rounded edges
if rounded_edges:
    bottom_base=bottom_base.fillet(2)
bottom_base

# %%
# Add corners for screw/plugs
corner=cq.Workplane().circle(corner_radius).extrude(base_height - wall_thickness)
positions = [
    (-(base_width/2 - wall_thickness), -(base_length/2 - wall_thickness)),
    (-(base_width/2 - wall_thickness), base_length/2 - wall_thickness),
    (base_width/2 - wall_thickness, -(base_length/2 - wall_thickness)),
    (base_width/2 - wall_thickness, base_length/2 - wall_thickness)
]
corners = cq.Workplane()
for pos in positions:
    corners = corners.union(corner.translate(pos))
bottom_base.union(corners)

# %%
# Add the screw holes or slots
if screws:
    # TODO
    pass
else:
    corner_slot=cq.Workplane().circle(corner_radius/2).extrude(wall_thickness)
    for pos in positions:
        corner_slots=
corner_slot

# %%
# Set top and bottom to the half_base
top_base, bottom_base = half_base, half_base
top_base

# %%
Add edge

# %%
# Add rounded edges
if rounded_edges:
    base=base.fillet(2)
base
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[86], line 3
#       1 # Add rounded edges
#       2 if rounded_edges:
# ----> 3     base=base.fillet(2)
#       4 base
#
# AttributeError: 'Assembly' object has no attribute 'fillet'
